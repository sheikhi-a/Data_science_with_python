# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikhi-a/Data_science_with_python/blob/main/python_ch6_of_paul_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course=('math', 'stat', 'physics', 'science')
student=('ali', 'hasan', 'reza')

# %%
scores=[[12,13,14, 13], [18, 17,19,17], [10,11,12,13]]
print(scores)
# Out:
# [[12, 13, 14, 13], [18, 17, 19, 17], [10, 11, 12, 13]]

# %%
import pandas as pd
import numpy as np
data=pd.DataFrame(scores)
print(data)
# Out:
#     0   1   2   3
# 0  12  13  14  13
# 1  18  17  19  17
# 2  10  11  12  13

# %%
 df=pd.DataFrame(data=scores, index=student, columns=course)
 print(df)
df

 #wrong : df=pd.DataFrame(data=data, index=student, columns=course)
# Out:
#        math  stat  physics  science
# ali      12    13       14       13
# hasan    18    17       19       17
# reza     10    11       12       13
#        math  stat  physics  science
# ali      12    13       14       13
# hasan    18    17       19       17
# reza     10    11       12       13

# %%
df.loc[:,'math']
# Out:
# ali      12
# hasan    18
# reza     10
# Name: math, dtype: int64

# %%
df.loc['ali',:]
df.loc['ali']
# Out:
# math       12
# stat       13
# physics    14
# science    13
# Name: ali, dtype: int64

# %%
df.loc['ali', ['math', 'science']]
# Out:
# math       12
# science    13
# Name: ali, dtype: int64

# %%
df.iloc[2]
df.iloc[2,:]
df.iloc[[2]]
# Out:
# math       10
# stat       11
# physics    12
# science    13
# Name: reza, dtype: int64

# %%
df.iloc[:,2]
# Out:
# ali      14
# hasan    19
# reza     12
# Name: physics, dtype: int64

# %%
# Out:
#       math  stat  physics  science
# reza    10    11       12       13

# %%
df.iloc[2, [1,2]]
# Out:
# stat       11
# physics    12
# Name: reza, dtype: int64

# %%
df.iloc[2, [0,2,3]]
# Out:
# math       10
# physics    12
# science    13
# Name: reza, dtype: int64

# %%
df.iloc[[1,2], [0,2]]
# Out:
#        math  physics
# hasan    18       19
# reza     10       12

# %%
df.iloc[:2, [0,2]]
# Out:
#        math  physics
# ali      12       14
# hasan    18       19

# %%
df.iloc[:, [0,2]] # all cases
# Out:
#        math  physics
# ali      12       14
# hasan    18       19
# reza     10       12

# %%
df.sort_values(by='math')
# Out:
#        math  stat  physics  science
# reza     10    11       12       13
# ali      12    13       14       13
# hasan    18    17       19       17

# %%
df.sort_values(by='math', ascending=False)
# Out:
#        math  stat  physics  science
# hasan    18    17       19       17
# ali      12    13       14       13
# reza     10    11       12       13

# %%
df.idxmax()  # name of stuent with max in eaxh lesson
# Out:
# math       hasan
# stat       hasan
# physics    hasan
# science    hasan
# dtype: object

# %%
dfnew=pd.DataFrame(np.insert(df.values, 3, values=[8, 9, 7,6], axis=0), columns=df.columns)

dfnew2=pd.DataFrame(np.insert(dfnew.values, 4, values=[18, 19, 17,16], axis=1))
dfnew2.columns=['math', 'stat', 'physics', 'science','art',]
#axis =0 means row, axis=1 means column
# Out:
#    math  stat  physics  science  art
# 0    12    13       14       13   18
# 1    18    17       19       17   19
# 2    10    11       12       13   17
# 3     8     9        7        6   16

# %%
data1 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Marie'],
    'Age': [25, 30, 35, 40, 20],
    'City': ['New York', 'Los Angeles', 'San Francisco', 'Chicago', 'Washington']
}

df1 = pd.DataFrame(data1)
print(df1)


new_row = {'Name': 'John', 'Age': 35, 'City': 'New York'}
df1.loc[len(df1)] = new_row
print(df1)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35  San Francisco
# 3    David   40        Chicago
# 4    Marie   20     Washington
# 5     John   35       New York

# %%
df_trans=df1.T
df_trans

df_trans_trans=df_trans.T
df_trans_trans
# Out:
#       Name Age           City
# 0    Alice  25       New York
# 1      Bob  30    Los Angeles
# 2  Charlie  35  San Francisco
# 3    David  40        Chicago
# 4    Marie  20     Washington
# 5     John  35       New York

# %%
df1.drop(['City'], axis=1) # axis 1 is tghe column
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4    Marie   20
# 5     John   35

# %%
df1.drop([3], axis=0) # same as df1.drop([3], axis=0)
df.drop(['ali'], axis=0) # same as df1.drop([3], axis=0)
# Out:
#        math  stat  physics  science
# hasan    18    17       19       17
# reza     10    11       12       13

# %%
#changes the data frame as well
df1.drop([3], axis=0, inplace=True)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35  San Francisco
# 4    Marie   20     Washington
# 5     John   35       New York

# %%
df1.empty #empthy or not
df2=df1.drop(['City', 'Name', 'Age'], axis=1) # axis 1 is tghe column
df2.empty
# Out:
# True

# %%
df.describe()
# Out:
#             math       stat    physics    science
# count   3.000000   3.000000   3.000000   3.000000
# mean   13.333333  13.666667  15.000000  14.333333
# std     4.163332   3.055050   3.605551   2.309401
# min    10.000000  11.000000  12.000000  13.000000
# 25%    11.000000  12.000000  13.000000  13.000000
# 50%    12.000000  13.000000  14.000000  13.000000
# 75%    15.000000  15.000000  16.500000  15.000000
# max    18.000000  17.000000  19.000000  17.000000
